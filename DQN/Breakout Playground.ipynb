# %% [markdown]
# https://github.com/openai/universe-starter-agent/issues/98
#
# to install atari env
#
# ``
#  pip install "gym[atari]"
#  fatal error: zlib.h: No such file or directory
#  sudo apt-get install libz-dev
# ``

# %%
# %matplotlib inline
sys.path.append('/home/jovyan/work/gym')
import gym
import numpy as np
from matplotlib import pyplot as plt

# %%
env = gym.envs.make("Breakout-v0")
#To solve AttributeError: 'TimeLimit' object has no attribute 'get_action_meanings'
env = env.unwrapped
# Out:
# [2017-09-29 09:04:25,970] Making new env: Breakout-v0

# %%
print("Action space size: {}".format(env.action_space.n))
print(env.get_action_meanings())

observation = env.reset()
print("Observation space shape: {}".format(observation.shape))

plt.figure()
plt.imshow(env.render(mode='rgb_array'))

[env.step(2) for x in range(1)]
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

env.render(close=True)
# Out:
# Action space size: 4
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']
# Observation space shape: (210, 160, 3)

# %%
# Check out what a cropped image looks like
plt.imshow(observation[34:-16,:,:])
